# %% [markdown]
# <a href="https://colab.research.google.com/github/HrushhikeshMate/trial-and-error/blob/main/Copy_of_trial_n_nba_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import requests
import random
import time
from io import StringIO

# %%
# teams =['ATL']

# %%
teams = [
    'ATL', 'BOS', 'BRK', 'CHO', 'CHI', 'DAL', 'DEN', 'DET', 'GSW', 'HOU',
    'CLE', 'IND', 'LAC', 'LAL', 'MEM', 'MIA', 'MIL', 'MIN', 'NOP', 'NYK',
    'OKC', 'ORL', 'PHI', 'PHO', 'POR', 'SAC', 'SAS', 'TOR', 'UTA', 'WAS'
]

# %%
# team_dict ={
    # 'ATL': 'Atlanta Hawks'}

# %%
team_dict ={
    'ATL': 'Atlanta Hawks',
    'BOS': 'Boston Celtics',
    'BRK': 'Brooklyn Nets',
    'CHO': 'Charlotte Hornets',
    'CHI': 'Chicago Bulls',
    'CLE': 'Cleveland Cavaliers',
    'DAL': 'Dallas Mavericks',
    'DEN': 'Denver Nuggets',
    'DET': 'Detroit Pistons',
    'GSW': 'Golden State Warriors',
    'HOU': 'Houston Rockets',
    'IND': 'Indiana Pacers',
    'LAC': 'Los Angeles Clippers',
    'LAL': 'Los Angeles Lakers',
    'MEM': 'Memphis Grizzlies',
    'MIA': 'Miami Heat',
    'MIL': 'Milwaukee Bucks',
    'MIN': 'Minnesota Timberwolves',
    'NOP': 'New Orleans Pelicans',
    'NYK': 'New York Knicks',
    'OKC': 'Oklahoma City Thunder',
    'ORL': 'Orlando Magic',
    'PHI': 'Philadelphia 76ers',
    'PHO': 'Phoenix Suns',
    'POR': 'Portland Trail Blazers',
    'SAC': 'Sacramento Kings',
    'SAS': 'San Antonio Spurs',
    'TOR': 'Toronto Raptors',
    'UTA': 'Utah Jazz',
    'WAS': 'Washington Wizards'
}

# %%
seasons =['2019','2020','2021','2022','2023','2024']
#len(seasons)
#print(seasons)

for season in seasons:
  print(season)
# Out:
# 2019
# 2020
# 2021
# 2022
# 2023
# 2024

# %%
# Create an empty DataFrame to append
nba_df = pd.DataFrame()

# Iterate through seasons and teams
for season in seasons:
    for team in teams:
        url = f'https://www.basketball-reference.com/teams/{team}/{season}/gamelog-advanced/'
        print(url)

        response = requests.get(url, headers={'User-agent': 'Mozilla/5.0'})
        visible_html = response.text.replace('<!--', '').replace('-->', '')

        try:
            # Load all columns from the HTML
            team_df = pd.read_html(StringIO(visible_html), header=1)[0]

            # Data cleaning
            team_df = team_df.dropna(subset=['G'])  # Drop rows where 'G' is NaN
            team_df = team_df[team_df['G'] != 'G']  # Remove duplicate header rows
            team_df = team_df.rename(columns={'Unnamed: 3': 'At', 'Tm': 'OPts', 'Opp.1': 'DPts'})
            team_df['At'] = team_df['At'].apply(lambda x: x if x == '@' else "")
            team_df['Win'] = team_df['W/L'].apply(lambda x: 1 if x == 'W' else 0)
            team_df['Location'] = team_df['At'].apply(lambda x: 'Away' if x == '@' else 'Home')
            team_df['Opp_Name'] = team_df['Opp'].apply(lambda x: team_dict.get(x, 'Unknown'))
            team_df.insert(loc =6 , column= 'Location', value=team_df.pop('Location'))
            team_df.insert(loc =8 , column= 'Opp_Name', value=team_df.pop('Opp_Name'))

            # Add additional columns
            team_df.insert(0, 'Season', season)
            team_df.insert(2, 'Team', team)
            team_df.insert(3, 'Name', team_dict[team])

            # Append to aggregate DataFrame
            nba_df = pd.concat([nba_df, team_df], ignore_index=True)

        except Exception as e:
            print(f"Failed to process {team} in {season}: {e}")

        # Pause to abide by site rules
        time.sleep(random.randint(4, 6))

# Display all columns in the final DataFrame
print(nba_df.columns)
# Out:
# https://www.basketball-reference.com/teams/ATL/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/BOS/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/BRK/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/CHO/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/CHI/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/DAL/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/DEN/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/DET/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/GSW/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/HOU/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/CLE/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/IND/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/LAC/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/LAL/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/MEM/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIA/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIL/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIN/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/NOP/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/NYK/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/OKC/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/ORL/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/PHI/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/PHO/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/POR/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/SAC/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/SAS/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/TOR/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/UTA/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/WAS/2019/gamelog-advanced/
# https://www.basketball-reference.com/teams/ATL/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/BOS/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/BRK/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/CHO/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/CHI/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/DAL/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/DEN/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/DET/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/GSW/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/HOU/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/CLE/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/IND/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/LAC/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/LAL/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/MEM/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIA/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIL/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIN/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/NOP/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/NYK/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/OKC/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/ORL/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/PHI/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/PHO/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/POR/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/SAC/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/SAS/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/TOR/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/UTA/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/WAS/2020/gamelog-advanced/
# https://www.basketball-reference.com/teams/ATL/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/BOS/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/BRK/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/CHO/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/CHI/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/DAL/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/DEN/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/DET/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/GSW/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/HOU/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/CLE/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/IND/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/LAC/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/LAL/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/MEM/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIA/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIL/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIN/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/NOP/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/NYK/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/OKC/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/ORL/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/PHI/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/PHO/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/POR/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/SAC/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/SAS/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/TOR/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/UTA/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/WAS/2021/gamelog-advanced/
# https://www.basketball-reference.com/teams/ATL/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/BOS/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/BRK/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/CHO/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/CHI/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/DAL/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/DEN/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/DET/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/GSW/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/HOU/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/CLE/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/IND/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/LAC/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/LAL/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/MEM/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIA/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIL/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIN/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/NOP/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/NYK/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/OKC/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/ORL/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/PHI/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/PHO/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/POR/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/SAC/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/SAS/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/TOR/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/UTA/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/WAS/2022/gamelog-advanced/
# https://www.basketball-reference.com/teams/ATL/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/BOS/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/BRK/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/CHO/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/CHI/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/DAL/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/DEN/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/DET/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/GSW/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/HOU/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/CLE/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/IND/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/LAC/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/LAL/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/MEM/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIA/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIL/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIN/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/NOP/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/NYK/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/OKC/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/ORL/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/PHI/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/PHO/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/POR/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/SAC/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/SAS/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/TOR/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/UTA/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/WAS/2023/gamelog-advanced/
# https://www.basketball-reference.com/teams/ATL/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/BOS/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/BRK/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/CHO/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/CHI/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/DAL/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/DEN/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/DET/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/GSW/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/HOU/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/CLE/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/IND/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/LAC/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/LAL/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/MEM/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIA/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIL/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIN/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/NOP/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/NYK/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/OKC/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/ORL/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/PHI/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/PHO/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/POR/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/SAC/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/SAS/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/TOR/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/UTA/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/WAS/2024/gamelog-advanced/
# Index(['Season', 'Rk', 'Team', 'Name', 'G', 'Date', 'At', 'Opp', 'W/L',
#        'Location', 'OPts', 'Opp_Name', 'DPts', 'ORtg', 'DRtg', 'Pace', 'FTr',
#        '3PAr', 'TS%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'Unnamed: 18', 'eFG%',
#        'TOV%', 'ORB%', 'FT/FGA', 'Unnamed: 23', 'eFG%.1', 'TOV%.1', 'DRB%',
#        'FT/FGA.1', 'Win'],
#       dtype='object')

# %%
nba_df
# Out:
#       Season  Rk Team                Name   G        Date At  Opp W/L  \
# 0       2019   1  ATL       Atlanta Hawks   1  2018-10-17  @  NYK   L
# 1       2019   2  ATL       Atlanta Hawks   2  2018-10-19  @  MEM   L
# 2       2019   3  ATL       Atlanta Hawks   3  2018-10-21  @  CLE   W
# 3       2019   4  ATL       Atlanta Hawks   4  2018-10-24     DAL   W
# 4       2019   5  ATL       Atlanta Hawks   5  2018-10-27     CHI   L
# ...      ...  ..  ...                 ...  ..         ... ..  ...  ..
# 14113   2024  78  WAS  Washington Wizards  78  2024-04-05     POR   L
# 14114   2024  79  WAS  Washington Wizards  79  2024-04-07  @  TOR   L
# 14115   2024  80  WAS  Washington Wizards  80  2024-04-09  @  MIN   L
# 14116   2024  81  WAS  Washington Wizards  81  2024-04-12     CHI   L
# 14117   2024  82  WAS  Washington Wizards  82  2024-04-14  @  BOS   L
#
#       Location  ...  eFG%  TOV%  ORB% FT/FGA Unnamed: 23 eFG%.1 TOV%.1  DRB%  \
# 0         Away  ...  .511  19.7  16.3   .167         NaN   .515   12.4  79.2
# 1         Away  ...  .578  16.1  24.4   .253         NaN   .623   14.5  80.6
# 2         Away  ...  .602  10.1  20.9   .153         NaN   .515   14.6  70.0
# 3         Home  ...  .489  12.5  18.9   .242         NaN   .484   14.2  83.0
# 4         Home  ...  .393  18.9  20.0   .226         NaN   .506   20.3  82.2
# ...        ...  ...   ...   ...   ...    ...         ...    ...    ...   ...
# 14113     Home  ...  .460   9.0  23.5   .239         NaN   .484   11.1  67.3
# 14114     Away  ...  .562  12.8  16.3   .247         NaN   .568   11.4  81.4
# 14115     Away  ...  .607  11.9  17.1   .146         NaN   .578    7.1  77.3
# 14116     Home  ...  .628  10.8   9.3   .221         NaN   .561   10.5  67.3
# 14117     Away  ...  .544  10.1  17.4   .097         NaN   .663   14.8  73.7
#
#       FT/FGA.1 Win
# 0         .242   0
# 1         .370   0
# 2         .091   1
# 3         .176   1
# 4         .157   0
# ...        ...  ..
# 14113     .181   0
# 14114     .219   0
# 14115     .289   0
# 14116     .194   0
# 14117     .157   0
#
# [14118 rows x 34 columns]

# %%
nba_df.drop(columns=['Unnamed: 18','Unnamed: 23'])
# Out:
#       Season  Rk Team                Name   G        Date At  Opp W/L  \
# 0       2019   1  ATL       Atlanta Hawks   1  2018-10-17  @  NYK   L
# 1       2019   2  ATL       Atlanta Hawks   2  2018-10-19  @  MEM   L
# 2       2019   3  ATL       Atlanta Hawks   3  2018-10-21  @  CLE   W
# 3       2019   4  ATL       Atlanta Hawks   4  2018-10-24     DAL   W
# 4       2019   5  ATL       Atlanta Hawks   5  2018-10-27     CHI   L
# ...      ...  ..  ...                 ...  ..         ... ..  ...  ..
# 14113   2024  78  WAS  Washington Wizards  78  2024-04-05     POR   L
# 14114   2024  79  WAS  Washington Wizards  79  2024-04-07  @  TOR   L
# 14115   2024  80  WAS  Washington Wizards  80  2024-04-09  @  MIN   L
# 14116   2024  81  WAS  Washington Wizards  81  2024-04-12     CHI   L
# 14117   2024  82  WAS  Washington Wizards  82  2024-04-14  @  BOS   L
#
#       Location  ...  BLK%  eFG%  TOV%  ORB% FT/FGA eFG%.1 TOV%.1  DRB%  \
# 0         Away  ...   4.5  .511  19.7  16.3   .167   .515   12.4  79.2
# 1         Away  ...   9.1  .578  16.1  24.4   .253   .623   14.5  80.6
# 2         Away  ...   9.7  .602  10.1  20.9   .153   .515   14.6  70.0
# 3         Home  ...  11.8  .489  12.5  18.9   .242   .484   14.2  83.0
# 4         Home  ...  16.0  .393  18.9  20.0   .226   .506   20.3  82.2
# ...        ...  ...   ...   ...   ...   ...    ...    ...    ...   ...
# 14113     Home  ...   7.7  .460   9.0  23.5   .239   .484   11.1  67.3
# 14114     Away  ...  16.9  .562  12.8  16.3   .247   .568   11.4  81.4
# 14115     Away  ...   8.2  .607  11.9  17.1   .146   .578    7.1  77.3
# 14116     Home  ...   7.9  .628  10.8   9.3   .221   .561   10.5  67.3
# 14117     Away  ...   7.0  .544  10.1  17.4   .097   .663   14.8  73.7
#
#       FT/FGA.1 Win
# 0         .242   0
# 1         .370   0
# 2         .091   1
# 3         .176   1
# 4         .157   0
# ...        ...  ..
# 14113     .181   0
# 14114     .219   0
# 14115     .289   0
# 14116     .194   0
# 14117     .157   0
#
# [14118 rows x 32 columns]

# %%
nba_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14118 entries, 0 to 14117
# Data columns (total 34 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Season       14118 non-null  object
#  1   Rk           14118 non-null  object
#  2   Team         14118 non-null  object
#  3   Name         14118 non-null  object
#  4   G            14118 non-null  object
#  5   Date         14118 non-null  object
#  6   At           14118 non-null  object
#  7   Opp          14118 non-null  object
#  8   W/L          14118 non-null  object
#  9   Location     14118 non-null  object
#  10  OPts         14118 non-null  object
#  11  Opp_Name     14118 non-null  object
#  12  DPts         14118 non-null  object
#  13  ORtg         14118 non-null  object
#  14  DRtg         14118 non-null  object
#  15  Pace         14118 non-null  object
#  16  FTr          14118 non-null  object
#  17  3PAr         14118 non-null  object
#  18  TS%          14118 non-null  object
#  19  TRB%         14118 non-null  object
#  20  AST%         14118 non-null  object
#  21  STL%         14118 non-null  object
#  22  BLK%         14118 non-null  object
#  23  Unnamed: 18  0 non-null      float64
#  24  eFG%         14118 non-null  object
#  25  TOV%         14118 non-null  object
#  26  ORB%         14118 non-null  object
#  27  FT/FGA       14118 non-null  object
#  28  Unnamed: 23  0 non-null      float64
#  29  eFG%.1       14118 non-null  object
#  30  TOV%.1       14118 non-null  object
#  31  DRB%         14118 non-null  object
#  32  FT/FGA.1     14118 non-null  object
#  33  Win          14118 non-null  int64
# dtypes: float64(2), int64(1), object(31)
# memory usage: 3.7+ MB

# %%
nba_df.to_csv('2019-2024_nba.csv', index=False)
